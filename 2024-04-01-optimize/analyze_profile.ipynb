# %%
import Profile
# import StatProfilerHTML.statprofilehtml
import Serialization

# %%
# cd("..")

# %%
# BEFORE CHANGES
data_before, lidict_before = Serialization.deserialize("output/before/runs/c2/r1/profile_data");
# Profile.print(data, lidict, mincount = 50)
Profile.print(IOContext(stdout, :displaysize => (24, 5000)), data_before, lidict_before, mincount = 10)
# statprofilehtml(data_before, lidict_before; path = "profile_before.html")
# Out:
# Overhead ╎ [+additional indent] Count File:Line; Function
# ...
#    ╎5267 @Base/client.jl:552; _start
#    ╎ 5267 @Base/client.jl:318; exec_options
#    ╎  5267 @Base/Base.jl:495; include
#    ╎   5267 @Base/loading.jl:2130; _include
#    ╎    5267 @Base/loading.jl:2070; include_string
#    ╎     5267 @Base/boot.jl:385; eval
#    ╎    ╎ 5267 /home/ed/Documents/varmodels/varmodel-test-history/2024-04-01-optimize/varmodel3-before/src/model.jl:70; run
#    ╎    ╎  5267 /home/ed/Documents/varmodels/varmodel-test-history/2024-04-01-optimize/varmodel3-before/src/model.jl:79; profile
#  29╎    ╎   5267 @Profile/src/Profile.jl:27; macro expansion
#    ╎    ╎    16   /home/ed/Documents/varmodels/varmodel-test-history/2024-04-01-optimize/varmodel3-before/src/model.jl:88; run_inner
#    ╎    ╎    60   /home/ed/Documents/varmodels/varmodel-test-history/2024-04-01-optimize/varmodel3-before/src/model.jl:108; run_inner
# ...

# %%
# AFTER CHANGES
data_after, lidict_after = Serialization.deserialize("output/after/runs/c2/r1/profile_data");
Profile.print(IOContext(stdout, :displaysize => (24, 5000)), data_after, lidict_after, mincount = 25)
#statprofilehtml(data_after, lidict_after; path = "profile_after.html")
# Out:
# Overhead ╎ [+additional indent] Count File:Line; Function
# ...
#    ╎4146 @Base/client.jl:552; _start
#    ╎ 4146 @Base/client.jl:318; exec_options
#    ╎  4146 @Base/Base.jl:495; include
#    ╎   4146 @Base/loading.jl:2130; _include
#    ╎    4146 @Base/loading.jl:2070; include_string
#    ╎     4146 @Base/boot.jl:385; eval
#    ╎    ╎ 4146 /home/ed/Documents/varmodels/varmodel-test-history/2024-04-01-optimize/varmodel3-after/src/model.jl:70; run
#    ╎    ╎  4146 /home/ed/Documents/varmodels/varmodel-test-history/2024-04-01-optimize/varmodel3-after/src/model.jl:79; profile
#   4╎    ╎   4146 @Profile/src/Profile.jl:27; macro expansion
#    ╎    ╎    49   /home/ed/Documents/varmodels/varmodel-test-history/2024-04-01-optimize/varmodel3-after/src/model.jl:109; run_inner
#    ╎    ╎    51   /home/ed/Documents/varmodels/varmodel-test-history/2024-04-01-optimize/varmodel3-after/src/model.jl:114; run_inner
# ...
