# %%
using SQLite
import SQLite.Stmt
import SQLite.tables
import SQLite.columns
import SQLite.DBInterface.execute
using Distributions

# %%
db1 = SQLite.DB("output/before/sweep_db_gathered.sqlite")
db2 = SQLite.DB("output/after/sweep_db_gathered.sqlite")
# Out:
# SQLite.DB("output/after/sweep_db_gathered.sqlite")

# %%
columns(db1, "param_combos")[:name][2:end]
# Out:
# 9-element Vector{String}:
#  "biting_rate"
#  "immigration_rate_fraction"
#  "immunity_loss_rate"
#  "n_genes_initial"
#  "switching_rate_A"
#  "switching_rate_BC"
#  "ectopic_recombination_rate_A"
#  "ectopic_recombination_rate_BC"
#  "functionality_BC"

# %%
import StatsAPI.pvalue
import StatsBase.mean
import StatsBase.mad
import HypothesisTests.ApproximateTwoSampleKSTest

# Functions to compare using K-S tests

"""
    Do K-S tests using SQLite queries that take one parameter, run_id.

    `db1` and `db2` are assumed to have identical parameter combinations labeled the same way,
    via the `combo_id` column in the `runs` table.

    The query should return a single value for the provided run_id.

    If values from db2 need to be extracted with a different query, provide a value for `q2`.
"""
function compare(db1, db2, q1; q2 = q1)
    combo_ids = get_combo_ids(db1)
    @assert all(combo_ids .== get_combo_ids(db2))
    [(combo_id, compare(db1, db2, combo_id, q1; q2 = q2)) for combo_id in combo_ids]
end

function get_combo_ids(db)
    [combo_id for (combo_id,) in execute(db, "SELECT DISTINCT combo_id FROM runs ORDER BY combo_id")]
end

function get_run_ids(db, combo_id)
    [run_id for (run_id,) in execute(db, "SELECT run_id FROM runs WHERE combo_id = ?", [combo_id])]
end

function compare(db1, db2, combo_id, q1; q2 = q1)
    v1 = query_values_for_combo_id(db1, combo_id, q1)
    mean1 = mean(v1)
    mad1 = mad(v1; center = mean1)

    v2 = query_values_for_combo_id(db2, combo_id, q2)
    mean2 = mean(v2)
    mad2 = mad(v2; center = mean2)

    (ApproximateTwoSampleKSTest(v1, v2), (mean1, mad1), (mean2, mad2))
end

function query_values_for_combo_id(db, combo_id, q)
    stmt = Stmt(db, q)
    run_ids = get_run_ids(db, combo_id)

    [query_value_for_run_id(stmt, run_id) for run_id in run_ids]
end

function query_value_for_run_id(stmt, run_id)
    for (value,) in execute(stmt, (run_id,))
        return value
    end
end
# Out:
# query_value_for_run_id (generic function with 1 method)

# %%
for (combo_id, (test, (mean1, mad1), (mean2, mad2))) in compare(
    db1, db2, "SELECT value FROM run_meta WHERE key = \"elapsed_time\" AND run_id = ?"
)
    println("Testing elapsed time for parameter combination $(combo_id)...")
    println("    (mean1 $(mean1), mad1 $(mad1))")
    println("    (mean2 $(mean2), mad2 $(mad2))")
    println("    p-value: $(pvalue(test))")
    if pvalue(test) < 0.01
        println("    DIFFERENT distributions w/ p < 0.01")
    else
        println("    undetectable difference between distributions w/ p < 0.01")
    end
    println("    fractional difference: $((mean2 - mean1) / mean1)")
end
# Out:
# Testing elapsed time for parameter combination 1...
#     (mean1 276.54106666666667, mad1 7.190719599900106)
#     (mean2 445.5519999999999, mad2 10.197338058881677)
#     p-value: 6.118046410036549e-7
#     DIFFERENT distributions w/ p < 0.01
#     fractional difference: 0.61116034363552
# Testing elapsed time for parameter combination 2...
#     (mean1 1975.3434666666665, mad1 10.734731943015476)
#     (mean2 2451.4577999999997, mad2 19.502446102666983)
#     p-value: 6.118046410036549e-7
#     DIFFERENT distributions w/ p < 0.01
#     fractional difference: 0.24102863191521928
# Testing elapsed time for parameter combination 3...
#     (mean1 273.6126666666667, mad1 7.22422641003835)
#     (mean2 440.05973333333327, mad2 7.530532028381662)
#     p-value: 6.118046410036549e-7
#     DIFFERENT distributions w/ p < 0.01
#     fractional difference: 0.6083309983212273
# Testing elapsed time for parameter combination 4...
#     (mean1 489.5032, mad1 4.203473809907062)
#     (mean2 694.9358666666667, mad2 14.282104851160158)
#     p-value: 6.118046410036549e-7
#     DIFFERENT distributions w/ p < 0.01
#     fractional difference: 0.4196758400489858
# Testing elapsed time for parameter combination 5...
#     (mean1 279.88733333333334, mad1 3.6066769968846)
#     (mean2 446.79119999999995, mad2 10.938342647690682)
#     p-value: 6.118046410036549e-7
#     DIFFERENT distributions w/ p < 0.01
#     fractional difference: 0.5963251879923109
# Testing elapsed time for parameter combination 6...
#     (mean1 464.13079999999997, mad1 6.682384719248466)
#     (mean2 656.0940666666667, mad2 14.259569297438967)
#     p-value: 6.118046410036549e-7
#     DIFFERENT distributions w/ p < 0.01
#     fractional difference: 0.41359734511621876
# Testing elapsed time for parameter combination 7...
#     (mean1 499.14153333333337, mad1 4.146047683976892)
#     (mean2 784.6450000000001, mad2 17.551045062669093)
#     p-value: 6.118046410036549e-7
#     DIFFERENT distributions w/ p < 0.01
#     fractional difference: 0.571989000314273
# Testing elapsed time for parameter combination 8...
#     (mean1 282.9485333333333, mad1 5.343990276529577)
#     (mean2 447.4791333333333, mad2 9.23641414099412)
#     p-value: 6.118046410036549e-7
#     DIFFERENT distributions w/ p < 0.01
#     fractional difference: 0.5814859616401384
# Testing elapsed time for parameter combination 9...
#     (mean1 280.74139999999994, mad1 5.222614574907934)
#     (mean2 439.46393333333344, mad2 10.268404125222045)
#     p-value: 6.118046410036549e-7
#     DIFFERENT distributions w/ p < 0.01
#     fractional difference: 0.5653691736713343
# Testing elapsed time for parameter combination 10...
#     (mean1 277.79013333333324, mad1 6.935415497873563)
#     (mean2 438.2651333333333, mad2 11.770576693011728)
#     p-value: 6.118046410036549e-7
#     DIFFERENT distributions w/ p < 0.01
#     fractional difference: 0.5776843046021317
# Testing elapsed time for parameter combination 11...
#     (mean1 305.2912, mad1 7.8382214087953725)
#     (mean2 450.8131333333333, mad2 14.87475037797092)
#     p-value: 6.118046410036549e-7
#     DIFFERENT distributions w/ p < 0.01
#     fractional difference: 0.4766659940847732
# Testing elapsed time for parameter combination 12...
#     (mean1 551.7286, mad1 6.543316631152659)
#     (mean2 806.9257999999999, mad2 18.41718127872042)
#     p-value: 6.118046410036549e-7
#     DIFFERENT distributions w/ p < 0.01
#     fractional difference: 0.4625411841981725

# %% [markdown]
# ## Mean # active infected hosts from 90 to 100 years

# %%
for (combo_id, (test, (mean1, mad1), (mean2, mad2))) in compare(
    db1, db2, "SELECT AVG(n_infected_active) FROM summary WHERE run_id = ? AND (time >= 90 * 360) AND (time <= 100 * 360)"
)
    println("Testing mean infected for parameter combination $(combo_id)...")
    println("    (mean1 $(mean1), mad1 $(mad1))")
    println("    (mean2 $(mean2), mad2 $(mad2))")
    println("    p-value: $(pvalue(test))")
    if pvalue(test) < 0.01
        println("    DIFFERENT distributions w/ p < 0.01")
    else
        println("    undetectable difference between distributions w/ p < 0.01")
    end
    println("    fractional difference: $((mean1 - mean2) / mean1)")
end
# Out:
# Testing mean infected for parameter combination 1...
#     (mean1 566.8132231404959, mad1 40.515475171162066)
#     (mean2 542.7283746556473, mad2 32.09200736001613)
#     p-value: 0.07626242398653403
#     undetectable difference between distributions w/ p < 0.01
#     fractional difference: 0.042491684211959056
# Testing mean infected for parameter combination 2...
#     (mean1 829.3856749311293, mad1 13.192300732157038)
#     (mean2 809.2567493112948, mad2 12.72995756098681)
#     p-value: 0.0025452675974334303
#     DIFFERENT distributions w/ p < 0.01
#     fractional difference: 0.024269680835162677
# Testing mean infected for parameter combination 3...
#     (mean1 512.9944903581268, mad1 44.08188910284007)
#     (mean2 561.7123966942148, mad2 35.86672077693866)
#     p-value: 0.02805685626145722
#     undetectable difference between distributions w/ p < 0.01
#     fractional difference: -0.0949676989748517
# Testing mean infected for parameter combination 4...
#     (mean1 939.1267217630851, mad1 10.002459595372125)
#     (mean2 933.2016528925619, mad2 9.993474127381695)
#     p-value: 0.3752065498718389
#     undetectable difference between distributions w/ p < 0.01
#     fractional difference: 0.006309126056385318
# Testing mean infected for parameter combination 5...
#     (mean1 530.3465564738292, mad1 25.572641902223896)
#     (mean2 547.1526170798898, mad2 31.07910005921901)
#     p-value: 0.6603860200299694
#     undetectable difference between distributions w/ p < 0.01
#     fractional difference: -0.03168882761830448
# Testing mean infected for parameter combination 6...
#     (mean1 1001.2247933884298, mad1 13.260100172452642)
#     (mean2 991.0550964187327, mad2 31.80447238430588)
#     p-value: 0.3752065498718389
#     undetectable difference between distributions w/ p < 0.01
#     fractional difference: 0.010157256429178113
# Testing mean infected for parameter combination 7...
#     (mean1 1348.4545454545453, mad1 21.18528294046478)
#     (mean2 1316.9779614325066, mad2 17.566589922294188)
#     p-value: 0.00903316105294586
#     DIFFERENT distributions w/ p < 0.01
#     fractional difference: 0.02334271045927494
# Testing mean infected for parameter combination 8...
#     (mean1 554.8931129476584, mad1 30.753989490092167)
#     (mean2 549.1707988980714, mad2 27.16061915444119)
#     p-value: 0.18130044993812283
#     undetectable difference between distributions w/ p < 0.01
#     fractional difference: 0.01031246183465746
# Testing mean infected for parameter combination 9...
#     (mean1 561.1531680440771, mad1 35.87080508057104)
#     (mean2 540.9619834710744, mad2 26.804467877709495)
#     p-value: 0.02805685626145722
#     undetectable difference between distributions w/ p < 0.01
#     fractional difference: 0.03598159241153344
# Testing mean infected for parameter combination 10...
#     (mean1 543.6964187327825, mad1 44.30325835970774)
#     (mean2 535.4231404958679, mad2 34.501746503041716)
#     p-value: 0.9250856809941739
#     undetectable difference between distributions w/ p < 0.01
#     fractional difference: 0.015216723803694569
# Testing mean infected for parameter combination 11...
#     (mean1 572.1537190082646, mad1 25.297359837410617)
#     (mean2 541.6881542699725, mad2 40.37007396185409)
#     p-value: 0.07626242398653403
#     undetectable difference between distributions w/ p < 0.01
#     fractional difference: 0.05324716719677917
# Testing mean infected for parameter combination 12...
#     (mean1 870.4958677685951, mad1 21.160777118670833)
#     (mean2 838.5553719008263, mad2 25.03514754421998)
#     p-value: 0.00903316105294586
#     DIFFERENT distributions w/ p < 0.01
#     fractional difference: 0.03669230038925298

# %% [markdown]
# ## Mean # circulating genes from 90 to 100 years

# %%
for (combo_id, (test, (mean1, mad1), (mean2, mad2))) in compare(
    db1, db2, "SELECT AVG(n_circulating_genes_blood) FROM gene_strain_counts WHERE run_id = ? AND (time >= 90 * 360) AND (time <= 100 * 360)"
)
    println("Testing mean infected for parameter combination $(combo_id)...")
    println("    (mean1 $(mean1), mad1 $(mad1))")
    println("    (mean2 $(mean2), mad2 $(mad2))")
    println("    p-value: $(pvalue(test))")
    if pvalue(test) < 0.01
        println("    DIFFERENT distributions w/ p < 0.01")
    else
        println("    undetectable difference between distributions w/ p < 0.01")
    end
    println("    fractional difference: $((mean1 - mean2) / mean1)")
end
# Out:
# Testing mean infected for parameter combination 1...
#     (mean1 1130.4727272727273, mad1 191.4982938229782)
#     (mean2 1059.7454545454543, mad2 101.19434051400086)
#     p-value: 0.18130044993812283
#     undetectable difference between distributions w/ p < 0.01
#     fractional difference: 0.06256433350488956
# Testing mean infected for parameter combination 2...
#     (mean1 2587.8909090909087, mad1 171.3349036513025)
#     (mean2 2518.5939393939398, mad2 114.90616466818028)
#     p-value: 0.18130044993812283
#     undetectable difference between distributions w/ p < 0.01
#     fractional difference: 0.02677739214336205
# Testing mean infected for parameter combination 3...
#     (mean1 975.3151515151515, mad1 123.53221393948517)
#     (mean2 1128.8909090909094, mad2 104.15954495101207)
#     p-value: 0.0025452675974334303
#     DIFFERENT distributions w/ p < 0.01
#     fractional difference: -0.15746270047909963
# Testing mean infected for parameter combination 4...
#     (mean1 9083.97575757576, mad1 38.044471473650596)
#     (mean2 9049.448484848483, mad2 31.79957121994412)
#     p-value: 0.07626242398653403
#     undetectable difference between distributions w/ p < 0.01
#     fractional difference: 0.0038008988188329433
# Testing mean infected for parameter combination 5...
#     (mean1 1062.6424242424243, mad1 91.23844198003559)
#     (mean2 1067.7333333333333, mad2 135.19535139172908)
#     p-value: 0.9250856809941739
#     undetectable difference between distributions w/ p < 0.01
#     fractional difference: -0.004790801660811164
# Testing mean infected for parameter combination 6...
#     (mean1 1602.1575757575754, mad1 93.50277991375286)
#     (mean2 1562.0363636363638, mad2 106.55866490459336)
#     p-value: 0.3752065498718389
#     undetectable difference between distributions w/ p < 0.01
#     fractional difference: 0.025041988833239676
# Testing mean infected for parameter combination 7...
#     (mean1 2562.7757575757573, mad1 178.91863863565828)
#     (mean2 2440.3454545454542, mad2 116.74818560632328)
#     p-value: 0.18130044993812283
#     undetectable difference between distributions w/ p < 0.01
#     fractional difference: 0.04777253829890888
# Testing mean infected for parameter combination 8...
#     (mean1 1108.4969696969697, mad1 181.20993297334834)
#     (mean2 1049.739393939394, mad2 82.50456709283897)
#     p-value: 0.3752065498718389
#     undetectable difference between distributions w/ p < 0.01
#     fractional difference: 0.05300652808607888
# Testing mean infected for parameter combination 9...
#     (mean1 994.230303030303, mad1 147.3796459874479)
#     (mean2 970.2848484848486, mad2 81.79471512155445)
#     p-value: 0.18130044993812283
#     undetectable difference between distributions w/ p < 0.01
#     fractional difference: 0.02408441431776059
# Testing mean infected for parameter combination 10...
#     (mean1 1302.0787878787878, mad1 124.92496147808109)
#     (mean2 1252.50303030303, mad2 178.52327804405613)
#     p-value: 0.3752065498718389
#     undetectable difference between distributions w/ p < 0.01
#     fractional difference: 0.03807431473215337
# Testing mean infected for parameter combination 11...
#     (mean1 1152.8848484848486, mad1 118.84179964821278)
#     (mean2 1096.8969696969696, mad2 126.84785162814318)
#     p-value: 0.3752065498718389
#     undetectable difference between distributions w/ p < 0.01
#     fractional difference: 0.048563287878628784
# Testing mean infected for parameter combination 12...
#     (mean1 1295.951515151515, mad1 95.2190043000231)
#     (mean2 1275.6727272727271, mad2 169.09752212155735)
#     p-value: 0.9250856809941739
#     undetectable difference between distributions w/ p < 0.01
#     fractional difference: 0.015647798271540257
